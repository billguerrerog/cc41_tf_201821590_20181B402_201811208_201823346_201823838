# %% [markdown]
# <a href="https://colab.research.google.com/github/billguerrerog/cc41_tf_201821590_20181B402_201811208_201823346_201823838/blob/main/DataSet_Generator_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random as r
from google.colab import files

data_alm = []

while len(data_alm) < 100:
    x = r.randint(0, 1000)
    y = r.randint(0, 1000)
    
    new_coord = [x, y]
    if new_coord not in data_alm:
        data_alm.append(new_coord)

df = pd.DataFrame(data_alm, columns= ['Coord X', 'Coord Y'])
df.to_csv(r'data_alm.csv')
#files.download("data_alm.csv")
df
# Out:
#     Coord X  Coord Y
# 0       862      171
# 1       430      239
# 2       164      350
# 3        74      561
# 4       532      501
# ..      ...      ...
# 95      406      200
# 96      748      249
# 97      185      965
# 98      253      553
# 99      283      886
#
# [100 rows x 2 columns]

# %%
import pandas as pd
import random as r
from google.colab import files

data_ent = []

while len(data_ent) < 5000:
    x = r.randint(0, 1000)
    y = r.randint(0, 1000)
    
    new_coord = [x, y]
    if new_coord not in data_ent and new_coord not in data_alm:
        data_ent.append(new_coord)

df2 = pd.DataFrame(data_ent, columns= ['Coord X', 'Coord Y'])
df2.to_csv(r'data_ent.csv')
#files.download("data_ent.csv")
df2
# Out:
#       Coord X  Coord Y
# 0         597      421
# 1         297      831
# 2         546      728
# 3         297      755
# 4         192      486
# ...       ...      ...
# 4995      872       38
# 4996      163      365
# 4997      158      280
# 4998      704      869
# 4999      872      792
#
# [5000 rows x 2 columns]

# %%
import pandas as pd
import math as m
from google.colab import files

df3 = pd.DataFrame()
data = list()
cont, cont2 = 0, 0

for x1, y1 in data_ent:
    cont2 = 0
    for x2, y2 in data_alm:
      data.append(m.sqrt(pow(x2-x1,2)+pow((y2 - y1), 2)))
      cont2 += 1
    df3[cont] = data
    cont += 1
    data.clear()

df3.to_csv(r'data_cost.csv')
#files.download("data_cost.csv")

df3
# Out:
#           0           1           2     ...        4997        4998        4999
# 0   364.314425  868.806653  640.394410  ...  712.388237  715.659137  621.080510
# 1   247.008097  606.756129  502.570393  ...  275.072718  687.005095  707.935732
# 2   438.782406  499.049096  537.408597  ...   70.256672  748.973297  834.642438
# 3   541.413890  350.184237  500.672548  ...  293.286549  701.258868  830.761699
# 4   103.077641  405.123438  227.431308  ...  434.415700  406.211767  447.527653
# ..         ...         ...         ...  ...         ...         ...         ...
# 95  292.099298  640.345219  546.245366  ...  260.583960  732.369442  753.405601
# 96  228.877697  736.291383  519.850940  ...  590.813845  621.559329  556.978456
# 97  682.407503  174.642492  431.844880  ...  685.531910  527.803941  708.447599
# 98  368.456239  281.460477  341.282874  ...  289.057088  550.687752  663.537490
# 99  561.089119   56.753854  306.811017  ...  618.757626  421.343091  596.453686
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

for x,y in data_ent:
    plt.plot(x, y, '.', color='blue')
for x,y in data_alm:
    plt.plot(x, y, '.', color='red')
cm = 1/2.54
plt.rcParams["figure.figsize"] = [60*cm, 30*cm]
plt.rcParams["figure.autolayout"] = True
plt.show()
