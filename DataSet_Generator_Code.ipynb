# %%
import pandas as pd
import random as r
from google.colab import files

import matplotlib.pyplot as plt
import numpy as np

import math as m

# %%
data_alm = []

while len(data_alm) < 100:
    x = r.randint(0, 999)
    y = r.randint(0, 999)
    
    new_coord = [x, y]
    if new_coord not in data_alm:
        data_alm.append(new_coord)

df = pd.DataFrame(data_alm, columns= ['Coord X', 'Coord Y'])
df.to_csv(r'data_alm.csv')
#files.download("data_alm.csv")
df
# Out:
#     Coord X  Coord Y
# 0        38      287
# 1        25      978
# 2       295      893
# 3       521      423
# 4        50      913
# ..      ...      ...
# 95      238      159
# 96      497      945
# 97      628       41
# 98      483       83
# 99      847      816
#
# [100 rows x 2 columns]

# %%
data_ent = []

while len(data_ent) < 5000:
    x = r.randint(0, 999)
    y = r.randint(0, 999)
    
    new_coord = [x, y]
    if new_coord not in data_ent and new_coord not in data_alm:
        data_ent.append(new_coord)

df2 = pd.DataFrame(data_ent, columns= ['Coord X', 'Coord Y'])
df2.to_csv(r'data_ent.csv')
#files.download("data_ent.csv")
df2
# Out:
#       Coord X  Coord Y
# 0         465      403
# 1         924      752
# 2         778      188
# 3         676      541
# 4         601      677
# ...       ...      ...
# 4995      639      965
# 4996      406      954
# 4997      275      358
# 4998      403      435
# 4999      208      332
#
# [5000 rows x 2 columns]

# %%
df3 = pd.DataFrame()
data = list()
cont, cont2 = 0, 0

for x1, y1 in data_ent:
    cont2 = 0
    for x2, y2 in data_alm:
      data.append(m.sqrt(pow(x2-x1,2)+pow((y2 - y1), 2)))
      cont2 += 1
    df3[cont] = data
    cont += 1
    data.clear()

df3.to_csv(r'data_cost.csv')
#files.download("data_cost.csv")
df3
# Out:
#           0            1            2     ...        4997        4998        4999
# 0   442.475988  1000.610314   746.592928  ...  247.406548  393.864190  175.855054
# 1   724.033839   926.971952  1091.379402  ...  668.505797  661.613936  671.420137
# 2   518.652099   644.609960   854.584109  ...  535.373701  470.561367  567.705910
# 3    59.464275   520.240329   348.244167  ...  254.442528  118.608600  325.960120
# 4   657.514258   888.705238  1027.428343  ...  598.873943  594.216291  602.100490
# ..         ...          ...          ...  ...         ...         ...         ...
# 95  333.264159   906.777260   540.778143  ...  202.410474  321.560259  175.581890
# 96  542.943828   468.591507   807.471362  ...  627.577087  518.590397  677.709377
# 97  397.005038   770.153881   210.021427  ...  474.444939  453.719076  510.960860
# 98  320.505850   801.275234   313.129366  ...  344.802842  360.976454  370.979784
# 99  562.577106   100.124922   631.779234  ...  732.767357  585.061535  801.609007
#
# [100 rows x 5000 columns]

# %%
for x,y in data_ent:
    plt.plot(x, y, '.', color='blue')
for x,y in data_alm:
    plt.plot(x, y, '.', color='red')
cm = 1/2.54
plt.rcParams["figure.figsize"] = [60*cm, 30*cm]
plt.rcParams["figure.autolayout"] = True
plt.show()
